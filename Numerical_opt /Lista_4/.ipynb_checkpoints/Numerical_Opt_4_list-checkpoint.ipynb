# %% [markdown]
# ## Szymon Czop 292913

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# $f(x) = cosh(x_1)+cosh(x_2)$ where $x_1, x_2 \in [-3,3]$

# %%
cosh = lambda x : np.cosh(x)
multi_cosh = lambda x: np.cosh(x[0]) + np.cosh(x[1])
grad_multi = lambda x : np.array([np.sinh(x[0]),np.sinh(x[1])])

# %% [markdown]
# The Hessian of such function is as we described in exercises $
# \begin{pmatrix}
# cosh(x1) & 0  \\
# 0 & cosh(x2)
# \end{pmatrix}$ and is bounded from below by 1 and from above by $cosh(3)$ or $cosh(-3)$ both equal to 10.06

# %%
M = cosh(3)
m = cosh(0)
k = M/m
step_size = 1/M
x_0 = [3,2]
x_optimal =[0,0]
eps=0.001
boundry = (1/np.log(k/(k-1)))*np.log((multi_cosh(x_0) - multi_cosh(x_optimal))/eps )
boundry
# Out:
# 89.64744404711816

# %%
def gradient(gradient_function,start_x): 
    """ta funkcja to jest najprostrzy gradient z możliwych nie ma tutaj zadnego dobotu t tylko 
        od razu narzucony z góry learning rate"""
    steps = [start_x]
    i = 0
    while True:
        i +=1
        direc = -gradient_function(start_x)
        grad_length = gradient_function(start_x) @ gradient_function(start_x)
        t =step_size
        start_x = start_x + t*direc
        steps.append(start_x)
        if(grad_length < eps):
            break
        #print(f"my points {start_x}")
    return start_x, i ,steps

# %%
x, iteration ,list_of_steps = gradient(grad_multi,x_0)
print(f"optimal point {x} reached after {iteration} iterations for upperboud equal {boundry}" )
# Out:
# optimal point [0.01987066 0.0178768 ] reached after 42 iterations for upperboud equal 89.64744404711816

# %% [markdown]
# Below I show gradient path  for random points, number of iterations made in evaluation of this point and comapare it to the upper bound number given in the formula

# %%
edge = 3
num_random_points = 10
rand_points=2*edge*np.random.rand(num_random_points,2) - edge
epss=1e-3

MX,MY = np.meshgrid(np.linspace(-3,3,100), np.linspace(-3,3,100))
Z = np.array([MX,MY]).reshape(2,-1)
VR = multi_cosh(Z)

for i in rand_points:
    boundry = (1/np.log(k/(k-1)))*np.log((multi_cosh(i) - multi_cosh(x_optimal))/eps )
    val,iteration,steps= gradient(grad_multi,i)
    plt.contour(MX,MY,VR.reshape(MX.shape), 100)
    path = pd.DataFrame(steps)
    plt.plot(path.iloc[:,0], path.iloc[:,1], '*-k')
    plt.show()
    print(f"iterations {iteration}, number of predicted evaluation {boundry}")
# Out:
# iterations 38, number of predicted evaluation 76.18211047400655
# iterations 40, number of predicted evaluation 79.14198931224776
# iterations 41, number of predicted evaluation 85.17447082009795
# iterations 38, number of predicted evaluation 70.98246447006585
# iterations 41, number of predicted evaluation 83.74314192913795
# iterations 41, number of predicted evaluation 83.04381057496053
# iterations 40, number of predicted evaluation 81.86711984378766
# iterations 39, number of predicted evaluation 73.93812517388905
# iterations 35, number of predicted evaluation 62.81445821862218
# iterations 36, number of predicted evaluation 65.78048220734709

# %% [markdown]
# ### Summmary and expalnation for first two bulletpoints
# This experiment shows us that number of evaluations tend to be smaller than the computed upperbound( its goood for us because we name it upper for some reasons ;)  ). In loop it is also clear how many times we use function and it's gradient. The function is used only once durning computation of upper boundry but gradient is evaluated in every loop of the function (the exit condition is also connected with the value of gradient) so the number of gradient computation is equal to number of iterations. So far we went throug the first 2 points of the list.

# %% [markdown]
# ### Rosenbrock example
#
# Belowe just to show another example I will use Rosebrock Fuction https://en.wikipedia.org/wiki/Rosenbrock_function it is not convex but widley use to check optimisation algorithm.

# %%
multi_rosenbrock = lambda x: (1 - x[0])**2 + 100*(x[1]- x[0]**2)**2
grad_rosenbrock = lambda x : np.array([2*(200*x[0]**3 - 200*x[0]*x[1] + x[0]-1),200*(x[1]-x[0]**2)])

M = multi_rosenbrock([5,5])
m = 1
k = M/m
step_size = 1/M

x_optimal = [0,0]
x_0 = [2,2]



eps=0.001
MX,MY = np.meshgrid(np.linspace(-5,5,100), np.linspace(-5,5,100))
Z = np.array([MX,MY]).reshape(2,-1)
VR = multi_rosenbrock(Z)
plt.contour(MX,MY,VR.reshape(MX.shape), 100)

# %%
boundry = (1/np.log(k/(k-1)))*np.log((multi_rosenbrock(x_0) - multi_rosenbrock(x_optimal))/eps )

# %% [markdown]
# There is a big probability that iteration of our function will go to Inf. For the safety reasons (of our kernel) we will put additional condition to exit loop, it will be number of needed iter

# %%
def gradient(gradient_function,start_x): 
    """ta funkcja to jest najprostrzy gradient z możliwych nie ma tutaj zadnego doboru t tylko 
        od razu narzucony z góry learning rate"""
    steps = [start_x]
    i = 0
    while True:
        i +=1
        direc = -gradient_function(start_x)
        grad_length = gradient_function(start_x) @ gradient_function(start_x)
        t =step_size
        start_x = start_x + t*direc
        steps.append(start_x)
        if(grad_length < eps or i > 10000 ):
            break
       # print(f"my points {i}")
    return start_x, i ,steps

# %%
point,iteration,steps = gradient(grad_rosenbrock,[2,2])
print(f"optimal point {x} reached after {iteration} iterations for upperboud equal {boundry}" )
# Out:
# optimal point [0.01987066 0.0178768 ] reached after 10001 iterations for upperboud equal 516168.73092307436

# %%
edge = 5
num_random_points = 10
rand_points=2*edge*np.random.rand(num_random_points,2) - edge
epss=1e-3

for i in rand_points:
    boundry = (1/np.log(k/(k-1)))*np.log((multi_rosenbrock (i) - multi_rosenbrock (x_optimal))/eps )
    val,iteration,steps= gradient(grad_rosenbrock,i)
    plt.contour(MX,MY,VR.reshape(MX.shape), 100)
    path = pd.DataFrame(steps)
    plt.plot(path.iloc[:,0], path.iloc[:,1], '*-k')
    plt.show()
    print(f"iterations {iteration}, number of predicted evaluation {boundry}")
# Out:
# iterations 10001, number of predicted evaluation 614827.2600492049
# iterations 10001, number of predicted evaluation 592270.2387239629
# iterations 10001, number of predicted evaluation 580501.7690258111
# iterations 10001, number of predicted evaluation 639667.3633461857
# iterations 10001, number of predicted evaluation 597675.3828087128
# iterations 10001, number of predicted evaluation 614790.4680789589
# iterations 10001, number of predicted evaluation 649857.5722119466
# iterations 10001, number of predicted evaluation 651367.3623976192
# iterations 10001, number of predicted evaluation 716425.7110977095
# iterations 10001, number of predicted evaluation 557150.3072147472

# %% [markdown]
# Fact that our iterations are always 10001 means that this function is super hard to optimize so our loop is ended not wehen gradient is small enough but weh number of iterations will exceed the limit. This is quiet normal for Rosenbrock function.

# %% [markdown]
# ##### WHEN STEP IS TOO LARGE

# %%
def gradient(gradient_function,start_x,step_size): 
    """ta funkcja to jest najprostszy gradient z możliwych nie ma tutaj zadnego doboru tylko 
        od razu narzucony z góry learning rate"""
    steps = [start_x]
    i = 0
    while True:
        i +=1
        direc = -gradient_function(start_x)
        grad_length = gradient_function(start_x) @ gradient_function(start_x)
        t = step_size
        start_x = start_x + t*direc
        steps.append(start_x)
        if(grad_length < eps or i > 10000 ):
            break
       # print(f"my points {i}")
    return start_x, i ,steps

# %%
len_of_step = np.arange(0.1,2+1e-10,0.1)

# %% [markdown]
# ### cosh function

# %%
import warnings
warnings.filterwarnings('ignore')# 'default' to turn it on 
x_0 = [2,2] # if we will chane this point 
for j in len_of_step:
    val,iteration,steps = gradient(grad_multi,x_0,j)
    print(f"optimal point {val} reached after {iteration} iterations for step_size = {round(j,2)}" )
# Out:
# optimal point [0.01924212 0.01924212] reached after 41 iterations for step_size = 0.1
# optimal point [0.01541223 0.01541223] reached after 20 iterations for step_size = 0.2
# optimal point [0.01126766 0.01126766] reached after 13 iterations for step_size = 0.3
# optimal point [0.00875637 0.00875637] reached after 9 iterations for step_size = 0.4
# optimal point [0.0057854 0.0057854] reached after 6 iterations for step_size = 0.5
# optimal point [-0.00446708 -0.00446708] reached after 5 iterations for step_size = 0.6
# optimal point [-0.00383061 -0.00383061] reached after 5 iterations for step_size = 0.7
# optimal point [-0.00312926 -0.00312926] reached after 4 iterations for step_size = 0.8
# optimal point [0.00189337 0.00189337] reached after 4 iterations for step_size = 0.9
# optimal point [-4.69250317e-13 -4.69250317e-13] reached after 5 iterations for step_size = 1.0
# optimal point [-0.00032091 -0.00032091] reached after 9 iterations for step_size = 1.1
# ...

# %% [markdown]
# ## Explanation
# We see that for point [2,2] the best step_size is about 1.0 because after just 5 iterations we are in our minimum. When step size is about 1.2 our algorythm does not converge, this is happening also for the larger step_size. If we will have point for which function is greater then in point [2,2], step_size for which algorythm does not converge will be smaller. (It's eazy to check by changing value of vecto x_0)

# %%
len_of_step = np.arange(0.0001,0.002,0.0001)
x_0 = [2,2] # if we will chane this point 
for j in len_of_step:
    val,iteration,steps = gradient(grad_rosenbrock,x_0,j)
    print(f"optimal point {val} reached after {iteration} iterations for step_size = {round(j,4)}" )
# Out:
# optimal point [1.3739842  1.88903451] reached after 10001 iterations for step_size = 0.0001
# optimal point [1.2909214 1.667458 ] reached after 10001 iterations for step_size = 0.0002
# optimal point [1.21944195 1.48780908] reached after 10001 iterations for step_size = 0.0003
# optimal point [1.15999212 1.34616343] reached after 10001 iterations for step_size = 0.0004
# optimal point [1.11233835 1.23771679] reached after 10001 iterations for step_size = 0.0005
# optimal point [1.07566226 1.15733859] reached after 10001 iterations for step_size = 0.0006
# optimal point [1.04861489 1.09978212] reached after 10001 iterations for step_size = 0.0007
# optimal point [1.03636901 1.0742031 ] reached after 9310 iterations for step_size = 0.0008
# optimal point [1.03637528 1.07421614] reached after 7717 iterations for step_size = 0.0009
# optimal point [1.03636169 1.07418791] reached after 6115 iterations for step_size = 0.001
# ...

# %% [markdown]
# ### Explanation
# For Rosenbrock we need much smaller step size, even starting from point quiet close to minimum (this is not eazy for this function) step_size has to be really small.

# %% [markdown]
# ### Comparation of fixed vs backtracking algorythm for the previous assingment.

# %%
def boyd_example_func(x, order=0):
    a=np.array([1,3])
    b=np.array([1,-3])
    c=np.array([-1,0])
    x=np.array(x)
    value = np.exp(a@x)+np.exp(b@x)+np.exp(c@x)
    if order==0:
        return value
    elif order==1:
        gradient = a.T*np.exp(a@x)+b.T*np.exp(b@x-0.1)+c.T*np.exp(c@x)
        return (value, gradient)
    elif order==2:
        gradient = a.T*np.exp(a@x)+b.T*np.exp(b@x)+c.T*np.exp(c@x)
        hessian = a.T*a*np.exp(a@x)+b.T*b*np.exp(b@x)+c.T*c*np.exp(c@x)
        return (value, gradient, hessian)
    else:
        raise ValueError("The argument order should be 0, 1 or 2")

# %%
boyd_func = lambda x : boyd_example_func(x,order = 0)
grad_boyd = lambda x : boyd_example_func(x,order = 1)[1]

# %%
x0= [1,1]
for step in [0.2,0.1,0.01,0.001]:
    val,iteration,steps = gradient(grad_boyd,[1,1],step)
    print(f"optimal point {val} reached after {iteration} iterations for step_size = {step} value {boyd_func(val)}" )     
print(f"starting from x_0 = {x0}")
# Out:
# optimal point [nan nan] reached after 10001 iterations for step_size = 0.2 value nan
# optimal point [nan nan] reached after 10001 iterations for step_size = 0.1 value nan
# optimal point [-0.31067378 -0.01666667] reached after 147 iterations for step_size = 0.01 value 2.8320827176397825
# optimal point [-0.31015143 -0.01666667] reached after 1623 iterations for step_size = 0.001 value 2.8321371121018366
# starting from x_0 = [1, 1]

# %% [markdown]
# ### Comparation with backtracking

# %%
def back_track_multi(function,gradient_function,alpha,beta,start_x):
    t =1
    direction =np.sign(-gradient_function(start_x)) #np.sign(- grad_fun_multi(start_x))
    while function(start_x + t*direction)> function(start_x)+ alpha*t*gradient_function(start_x).dot(direction):
        t = beta*t
        #print(f" Wartość funkcji {fun_multi(start_x + t*direction)} t-value = {t},dir = {direction}")
    return t 

#back_track_multi(boyd_func,grad_boyd,0.3,0.5,[0.01,0.01])

# %%
def gradient2(gradient_function,start_x,eps): 

    steps = [start_x]
    i = 0
    while True:
        i +=1
        direc = np.sign(-gradient_function(start_x))
        grad_length = gradient_function(start_x) @ gradient_function(start_x)
        t = back_track_multi(boyd_func,grad_boyd,0.3,0.001,start_x)
        start_x = start_x + t*direc
        steps.append(start_x)
        if(grad_length < eps or i > 1000 ):
            break
        #print(f"my points {i},I'm in point {start_x}")
    return start_x, i ,steps

# %%
val,iteration,steps = gradient2(grad_boyd,x0,step)
print(f"optimal point {val} reached after {iteration} iterations for step_size = {step} value {boyd_func(val)}" )     
print(f"starting from x_0 = {x0}")
# Out:
# optimal point [-0.001 -0.001] reached after 1001 iterations for step_size = 0.001 value 2.9990104908446993
# starting from x_0 = [1, 1]

# %% [markdown]
# This operation also give us minimum but not as accurate as previous fixed step_size. This method also has more computational problems. We can easilly see that fixed step size is not that bad idea

# %% [markdown]
# Pollynomial decay $1/\sqrt{k+1}$

# %%
x0 = [1,1]
eps = 0.001
def gradient(gradient_function,start_x): 
    steps = [start_x]
    i = 0
    while True:
        i +=1
        direc = np.sign(-gradient_function(start_x))
        grad_length = gradient_function(start_x) @ gradient_function(start_x)
        t =i/(i+1)
        start_x = start_x + t*direc
        steps.append(start_x)
        if(grad_length < eps or i > 1000):
            break
        #print(f"my points {start_x} {i}")
    return start_x, i ,steps

# %%
val,iteration,steps = gradient(grad_boyd,x0)
print(f"optimal point {val} reached after {iteration} ,value {boyd_func(val)}" )     
print(f"starting from x_0 = {x0}")
# Out:
# optimal point [-0.94710626  0.69264843] reached after 1001 ,value 5.725048336832998
# starting from x_0 = [1, 1]

# %% [markdown]
# This approach i the worst one, when it comes to function value
